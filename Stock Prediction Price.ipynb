# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
x = 5
print(x)
# Out:
# 5

# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.48-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from yfinance) (2.1.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from yfinance) (2.31.0)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.7.tar.gz (939 kB)
#      ---------------------------------------- 0.0/939.5 kB ? eta -:--:--
#       ------------------------------------ 20.5/939.5 kB 682.7 kB/s eta 0:00:02
#      ----------------------- -------------- 583.7/939.5 kB 9.2 MB/s eta 0:00:01
#      ------------------------------------- 939.5/939.5 kB 10.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from yfinance) (4.12.2)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\juanpablo.arangio\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2024.7.4)
# Downloading yfinance-0.2.48-py2.py3-none-any.whl (101 kB)
#    ---------------------------------------- 0.0/101.1 kB ? eta -:--:--
#    ---------------------------------------- 101.1/101.1 kB 5.7 MB/s eta 0:00:00
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#    ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#    ---------------------------------------- 112.2/112.2 kB 6.4 MB/s eta 0:00:00
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.7-py3-none-any.whl size=138951 sha256=0aca7e47c57a16de5c39aab10aeef834df281cfe06ca198f7adbfd422c4f02df
#   Stored in directory: c:\users\juanpablo.arangio\appdata\local\pip\cache\wheels\fd\28\34\9ba1363b76703fe35ae8296af28ea74578a41b83544bb9da65
# Successfully built peewee
# Installing collected packages: peewee, multitasking, html5lib, yfinance
# Successfully installed html5lib-1.1 multitasking-0.0.11 peewee-3.17.7 yfinance-0.2.48

# %%
import yfinance as yf
nasdaq = yf.Ticker('^NDX')

# %%
nasdaq = nasdaq.history(period='max')
nasdaq
# Out:
#                                    Open          High           Low  \
# Date
# 1985-10-01 00:00:00-04:00    110.620003    112.160004    110.565002
# 1985-10-02 00:00:00-04:00    112.139999    112.540001    110.779999
# 1985-10-03 00:00:00-04:00    110.839996    111.184998    110.120003
# 1985-10-04 00:00:00-04:00    110.870003    110.870003    109.855003
# 1985-10-07 00:00:00-04:00    110.074997    110.135002    108.175003
# ...                                 ...           ...           ...
# 2024-11-04 00:00:00-05:00  20011.550781  20106.990234  19898.570312
# 2024-11-05 00:00:00-05:00  20042.929688  20249.210938  20042.929688
# 2024-11-06 00:00:00-05:00  20571.289062  20807.029297  20526.640625
# 2024-11-07 00:00:00-05:00  20896.410156  21132.800781  20896.410156
# 2024-11-08 00:00:00-05:00  21083.580078  21155.000000  21050.320312
#
#                                   Close      Volume  Dividends  Stock Splits
# Date
# 1985-10-01 00:00:00-04:00    112.139999   153160000        0.0           0.0
# 1985-10-02 00:00:00-04:00    110.824997   164640000        0.0           0.0
# 1985-10-03 00:00:00-04:00    110.870003   147300000        0.0           0.0
# 1985-10-04 00:00:00-04:00    110.074997   147900000        0.0           0.0
# 1985-10-07 00:00:00-04:00    108.199997   128640000        0.0           0.0
# ...                                 ...         ...        ...           ...
# 2024-11-04 00:00:00-05:00  19963.599609  5762320000        0.0           0.0
# 2024-11-05 00:00:00-05:00  20227.460938  7060340000        0.0           0.0
# 2024-11-06 00:00:00-05:00  20781.330078  8138050000        0.0           0.0
# 2024-11-07 00:00:00-05:00  21101.570312  9232670000        0.0           0.0
# 2024-11-08 00:00:00-05:00  21117.179688  7316010000        0.0           0.0
#
# [9857 rows x 7 columns]

# %%
nasdaq.index
# Out:
# DatetimeIndex(['1985-10-01 00:00:00-04:00', '1985-10-02 00:00:00-04:00',
#                '1985-10-03 00:00:00-04:00', '1985-10-04 00:00:00-04:00',
#                '1985-10-07 00:00:00-04:00', '1985-10-08 00:00:00-04:00',
#                '1985-10-09 00:00:00-04:00', '1985-10-10 00:00:00-04:00',
#                '1985-10-11 00:00:00-04:00', '1985-10-14 00:00:00-04:00',
#                ...
#                '2024-10-28 00:00:00-04:00', '2024-10-29 00:00:00-04:00',
#                '2024-10-30 00:00:00-04:00', '2024-10-31 00:00:00-04:00',
#                '2024-11-01 00:00:00-04:00', '2024-11-04 00:00:00-05:00',
#                '2024-11-05 00:00:00-05:00', '2024-11-06 00:00:00-05:00',
#                '2024-11-07 00:00:00-05:00', '2024-11-08 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=9857, freq=None)

# %%
fig = px.line(nasdaq, y='Close')
fig.show()
# Out:
# c:\Users\juanpablo.arangio\AppData\Local\anaconda3\Lib\site-packages\_plotly_utils\basevalidators.py:106: FutureWarning: The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#   v = v.dt.to_pydatetime()

# %%
nasdaq = nasdaq.drop(columns=['Dividends', 'Stock Splits'])

nasdaq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 9857 entries, 1985-10-01 00:00:00-04:00 to 2024-11-08 00:00:00-05:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    9857 non-null   float64
#  1   High    9857 non-null   float64
#  2   Low     9857 non-null   float64
#  3   Close   9857 non-null   float64
#  4   Volume  9857 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 462.0 KB

# %%
nasdaq['Tomorrow'] = nasdaq['Close'].shift(-1)
nasdaq['Target'] = (nasdaq['Tomorrow'] > nasdaq['Close']).astype(int)

# %%
nasdaq
# Out:
#                                    Open          High           Low  \
# Date
# 1985-10-01 00:00:00-04:00    110.620003    112.160004    110.565002
# 1985-10-02 00:00:00-04:00    112.139999    112.540001    110.779999
# 1985-10-03 00:00:00-04:00    110.839996    111.184998    110.120003
# 1985-10-04 00:00:00-04:00    110.870003    110.870003    109.855003
# 1985-10-07 00:00:00-04:00    110.074997    110.135002    108.175003
# ...                                 ...           ...           ...
# 2024-11-04 00:00:00-05:00  20011.550781  20106.990234  19898.570312
# 2024-11-05 00:00:00-05:00  20042.929688  20249.210938  20042.929688
# 2024-11-06 00:00:00-05:00  20571.289062  20807.029297  20526.640625
# 2024-11-07 00:00:00-05:00  20896.410156  21132.800781  20896.410156
# 2024-11-08 00:00:00-05:00  21083.580078  21155.000000  21050.320312
#
#                                   Close      Volume      Tomorrow  Target
# Date
# 1985-10-01 00:00:00-04:00    112.139999   153160000    110.824997       0
# 1985-10-02 00:00:00-04:00    110.824997   164640000    110.870003       1
# 1985-10-03 00:00:00-04:00    110.870003   147300000    110.074997       0
# 1985-10-04 00:00:00-04:00    110.074997   147900000    108.199997       0
# 1985-10-07 00:00:00-04:00    108.199997   128640000    107.160004       0
# ...                                 ...         ...           ...     ...
# 2024-11-04 00:00:00-05:00  19963.599609  5762320000  20227.460938       1
# 2024-11-05 00:00:00-05:00  20227.460938  7060340000  20781.330078       1
# 2024-11-06 00:00:00-05:00  20781.330078  8138050000  21101.570312       1
# 2024-11-07 00:00:00-05:00  21101.570312  9232670000  21117.179688       1
# 2024-11-08 00:00:00-05:00  21117.179688  7316010000           NaN       0
#
# [9857 rows x 7 columns]

# %%
nasdaq = nasdaq.loc['2000-01-01':].copy()

# %%
s2=1
print(s2)
# Out:
# 1
